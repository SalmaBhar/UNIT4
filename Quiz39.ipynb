# %% [markdown]
# <a href="https://colab.research.google.com/github/SalmaBhar/UNIT4/blob/main/Quiz39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Quiz 39**

# %%
#Quiz 39
def narcissistic(m, n):
  nar_list=[]
  digits=[]
  sum=0
  for num in range(m+1, n):
    digits=str(num)
    for d in range(0, len(digits)):
      sum+=digits[d]*len(digits)
    if sum==num:
      nar_list.append(num)
  return (len(nar_list))

#tests
print(narcissistic(0, 100))
print(narcissistic(4, 59))
print(narcissistic(3, 6))

# %% [markdown]
# # **Flow Diagram**

# %% [markdown]
# ![2021-05-10.jpg](data:image/jpeg;base64,...)
